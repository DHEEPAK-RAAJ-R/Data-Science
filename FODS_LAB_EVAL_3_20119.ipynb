# %% [markdown]
# <a href="https://colab.research.google.com/github/DHEEPAK-RAAJ-R/Data-Science/blob/Lab/FODS_LAB_EVAL_3_20119.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
baby=pd.read_csv('/content/test.csv')

# %%
baby
# Out:
#       Unnamed: 0  Birth Weight  Gestational Days  Maternal Age  \
# 0              0           120               284            27
# 1              1           113               282            33
# 2              2           128               279            28
# 3              3           108               282            23
# 4              4           136               286            25
# ...          ...           ...               ...           ...
# 1169        1169           113               275            27
# 1170        1170           128               265            24
# 1171        1171           130               291            30
# 1172        1172           125               281            21
# 1173        1173           117               297            38
#
#       Maternal Height  Maternal Pregnancy Weight  Maternal Smoker
# 0                  62                        100            False
# 1                  64                        135            False
# ...

# %%
smoking_age=baby[['Maternal Age','Maternal Smoker']]
smoking_age
# Out:
#       Maternal Age  Maternal Smoker
# 0               27            False
# 1               33            False
# 2               28             True
# 3               23             True
# 4               25            False
# ...            ...              ...
# 1169            27            False
# 1170            24            False
# 1171            30             True
# 1172            21            False
# 1173            38            False
#
# [1174 rows x 2 columns]

# %%
smoker = smoking_age['Maternal Age'] [smoking_age['Maternal Smoker'] == True]
smoker
# Out:
# 2       28
# 3       23
# 8       30
# 10      32
# 11      23
#         ..
# 1162    28
# 1163    29
# 1164    21
# 1165    30
# 1171    30
# Name: Maternal Age, Length: 459, dtype: int64

# %%
non_smoker = smoking_age['Maternal Age'] [smoking_age['Maternal Smoker'] == True]
non_smoker
# Out:
# 2       28
# 3       23
# 8       30
# 10      32
# 11      23
#         ..
# 1162    28
# 1163    29
# 1164    21
# 1165    30
# 1171    30
# Name: Maternal Age, Length: 459, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
smoking_age.hist(by ='Maternal Smoker')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f60d1395df0>,
# ...
#       dtype=object)
