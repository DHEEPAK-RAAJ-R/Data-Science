# %% [markdown]
# <a href="https://colab.research.google.com/github/DHEEPAK-RAAJ-R/Data-Science/blob/Lab/20119_LABEVAL_1_FODS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1

# %%
import pandas as pd
df=pd.read_csv('/test1.csv')

# %% [markdown]
# Q2

# %%
df.describe()
# Out:
#                  39         77516            13          2174             0  \
# count  32560.000000  3.256000e+04  32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05     10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05      2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#                  40
# count  32560.000000
# mean      40.437469
# std       12.347618
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %% [markdown]
# Q3

# %%
df.head(3)
# Out:
#    39          State-gov   77516   Bachelors  13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 1  38            Private  215646     HS-grad   9             Divorced
# 2  53            Private  234721        11th   7   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White   Male  2174  0  40  \
# 0     Exec-managerial         Husband   White   Male     0  0  13
# 1   Handlers-cleaners   Not-in-family   White   Male     0  0  40
# 2   Handlers-cleaners         Husband   Black   Male     0  0  40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K

# %% [markdown]
# Q4

# %%
df.tail(4)
# Out:
#        39      State-gov   77516  Bachelors  13        Never-married  \
# 32556  40        Private  154374    HS-grad   9   Married-civ-spouse
# 32557  58        Private  151910    HS-grad   9              Widowed
# 32558  22        Private  201490    HS-grad   9        Never-married
# 32559  52   Self-emp-inc  287927    HS-grad   9   Married-civ-spouse
#
#              Adm-clerical  Not-in-family   White     Male   2174  0  40  \
# 32556   Machine-op-inspct        Husband   White     Male      0  0  40
# 32557        Adm-clerical      Unmarried   White   Female      0  0  40
# 32558        Adm-clerical      Own-child   White     Male      0  0  20
# 32559     Exec-managerial           Wife   White   Female  15024  0  40
#
#         United-States   <=50K
# 32556   United-States    >50K
# 32557   United-States   <=50K
# 32558   United-States   <=50K
# 32559   United-States    >50K

# %% [markdown]
# Q5

# %%
df.iloc[119]
# Out:
# 39                            21
#  State-gov               Private
# 77516                     199915
#  Bachelors          Some-college
# 13                            10
#  Never-married     Never-married
#  Adm-clerical      Other-service
#  Not-in-family         Own-child
#  White                     White
#  Male                     Female
# 2174                           0
# 0                              0
# 40                            40
#  United-States     United-States
#  <=50K                     <=50K
# Name: 119, dtype: object

# %% [markdown]
# Q6

# %%
df=df.rename(columns={" <=50K":"Income"})
df.columns
# Out:
# Index(['39', ' State-gov', '77516', ' Bachelors', '13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', '2174', '0', '40',
#        ' United-States', 'Income'],
#       dtype='object')

# %% [markdown]
# Q7

# %%
df["Income"].loc[32119]
# Out:
# ' <=50K'

# %% [markdown]
# Q8

# %%
df = df.set_axis([ 'age', 'type_employer', 'fnlwgt','education', 'education_num', 'marital','occupation','relationship', 'race','sex', 'capital_gain', 'capital_loss','hr_per_week', 'country', 'income'] , axis=1)

# %% [markdown]
# Q9

# %%
df.index
# Out:
# RangeIndex(start=0, stop=32560, step=1)

# %% [markdown]
# Q10

# %%
df.iloc[:2,:4]
# Out:
#    age      type_employer  fnlwgt   education
# 0   50   Self-emp-not-inc   83311   Bachelors
# 1   38            Private  215646     HS-grad

# %% [markdown]
# Q11

# %%
df.groupby(df.country).count()
# Out:
#                                age  type_employer  fnlwgt  education  \
# country
#  ?                             583            583     583        583
#  Cambodia                       19             19      19         19
#  Canada                        121            121     121        121
#  China                          75             75      75         75
#  Columbia                       59             59      59         59
#  Cuba                           95             95      95         95
#  Dominican-Republic             70             70      70         70
#  Ecuador                        28             28      28         28
#  El-Salvador                   106            106     106        106
#  England                        90             90      90         90
#  France                         29             29      29         29
#  Germany                       137            137     137        137
# ...

# %% [markdown]
# Q12

# %%
df.groupby(df.sex).count()
# Out:
#            age  type_employer  fnlwgt  education  education_num  marital  \
# sex
#  Female  10771          10771   10771      10771          10771    10771
#  Male    21789          21789   21789      21789          21789    21789
#
#          occupation  relationship   race  capital_gain  capital_loss  \
# sex
#  Female       10771         10771  10771         10771         10771
#  Male         21789         21789  21789         21789         21789
#
#          hr_per_week  country  income
# sex
#  Female        10771    10771   10771
#  Male          21789    21789   21789

# %% [markdown]
# Q13

# %%
female=df.loc[df.sex=="Female"]
male=df.loc[df.sex=="Male"]
print("high-income professionals Male:")
male.loc[df.income=='>50K']
print("high-income professionals Female:")
female.loc[df.income=='>50K']
# Out:
# high-income professionals Male:
# high-income professionals Female:
# Empty DataFrame
# Columns: [age, type_employer, fnlwgt, education, education_num, marital, occupation, relationship, race, sex, capital_gain, capital_loss, hr_per_week, country, income]
# Index: []

# %% [markdown]
#   Q14

# %%
male = len(df[(df.sex == " Male") & (df.income == " >50K")])
female = len(df[(df.sex == " Female") & (df.income == " >50K")])
percent= male*100/(male+female)

print(percent)
# Out:
# 84.96365259533223

# %% [markdown]
# Q15

# %%
import scipy
temp=pd.DataFrame(df["age"])
print("Skew: ",temp.skew())
print("Kurtosis: ",temp.kurt())
# Out:
# Skew:  age    0.558738
# dtype: float64
# Kurtosis:  age   -0.166212
# dtype: float64

# %% [markdown]
# Q16

# %%
m1 = len(df[(df.sex == " Male") & (df.income == " >50K")])
m = len(df[df.sex == " Male"])
print(m1/m)
# Out:
# 0.3057506081050071

# %% [markdown]
# Q17

# %%
print("Men: ",df.groupby("sex").mean()["age"][" Male"])
print("Women: ",df.groupby("sex").mean()["age"][" Female"])
# Out:
# Men:  39.433567396392675
# Women:  36.85823043357163

# %% [markdown]
# Q18

# %%
df.loc[df["sex"]==" Male"]["hr_per_week"].mean()
df.loc[df["sex"]==" Male"]["hr_per_week"].var()
# Out:
# 146.89493828365366

# %% [markdown]
# Q19

# %%
df["age"].median()
# Out:
# 37.0

# %% [markdown]
# Q20

# %%
df.loc[df["income"]==" >50K"]["age"].median()
# Out:
# 44.0

# %% [markdown]
# Q21

# %%
import matplotlib.pyplot as pt
pt.hist(df["age"][df.sex == " Male"],bins=20)
# Out:
# (array([1237., 1825., 1564., 2293., 2452., 1831., 2217., 2084., 1272.,
#         1550., 1119.,  755.,  695.,  400.,  182.,  147.,   83.,   38.,
#           13.,   32.]),
#  array([17.  , 20.65, 24.3 , 27.95, 31.6 , 35.25, 38.9 , 42.55, 46.2 ,
#         49.85, 53.5 , 57.15, 60.8 , 64.45, 68.1 , 71.75, 75.4 , 79.05,
#         82.7 , 86.35, 90.  ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# Q22

# %%
import seaborn as sns
sns.boxplot(x='age', y='income', data=df)
